# %%
from PIL import Image
import numpy as np
from resizeimage import resizeimage

# %%
sample_1=Image.open('test.png')
sample_1=sample_1.convert('L')
sample_1 = resizeimage.resize_cover(sample_1, [297, 297])
sample_2=temp.rotate(90)

# %%
sample_1
# Out:
# <PIL.Image._ImageCrop image mode=L size=297x297 at 0x7F38B31DB8D0>

# %%
sample_2
# Out:
# <PIL.Image.Image image mode=L size=297x297 at 0x7F38B31DBB90>

# %%
rgbArray = np.zeros((297,297,3), 'uint8')
rgbArray[:,:, 0] = temp1
rgbArray[:,:, 1] = temp2
rgbArray[:,:, 2] = np.ones((297,297),'uint8')*255
img = Image.fromarray(rgbArray)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=297x297 at 0x7F38B31DB3D0>

# %%
r,g,b=img.split()
